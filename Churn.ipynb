# %% [markdown]
# # Churn use case of a banking company

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %%
# Load the data and plot the top rows of the data set
Data = pd.read_csv("bankingchurn_data_modif.csv", sep = ";", decimal=',')
Data.head()
# Out:
#   contract_start contract_end date_of_birth gender             profession  \
# 0     2010-10-24          NaN    1991-02-11      M  Professional Services
# 1     2010-04-30   2017-10-20    1986-04-06      W                    NaN
# 2     2013-05-02          NaN    1993-04-18      M         Transportation
# 3     2016-12-24          NaN    1994-07-29      W  Professional Services
# 4     2011-10-01          NaN    1990-10-28      W               Research
#
#    size_household    ZIP segment  credit_rating  no_credit_rating_flag  ...  \
# 0               1  76829      S2      89.568518                      0  ...
# 1               1  35104      S2      94.270507                      0  ...
# 2               1  63450      S2      93.030947                      0  ...
# 3               2   9573      S3            NaN                      1  ...
# 4               1  66916      S2      90.457664                      0  ...
#
#    online_number_of_logins_per_month  online_tranactions_per_month  \
# 0                                  0                             0
# 1                                 16                             8
# 2                                 26                            12
# 3                                  0                             0
# 4                                 23                            18
#
#    advisor_contacts_last12months  customer_limit  cash_withdraws_per_month  \
# 0                              3          1000.0                         4
# 1                              2          1000.0                         7
# 2                              2          1000.0                         3
# 3                              4          1050.0                         4
# 4                              3          1000.0                         4
#
#    cash_withdrawals_value  consumer_credit_value  consumer_credit_maturity  \
# 0              459.840940          -24011.393552                       205
# 1              476.334459           -5368.743068                       137
# 2              332.640202           -9678.713419                       624
# 3              378.324744          -12110.305916                      1263
# 4              471.509299               0.000000                       521
#
#    account_fee  number_of_refusals
# 0           15                   6
# 1           15                   6
# 2           15                   4
# 3           10                   7
# 4           10                   3
#
# [5 rows x 44 columns]

# %%
# Display the data types of each column
Data.dtypes
# Out:
# contract_start                        object
# contract_end                          object
# date_of_birth                         object
# gender                                object
# profession                            object
# size_household                         int64
# ZIP                                   object
# segment                               object
# credit_rating                        float64
# no_credit_rating_flag                  int64
# main_account_flag                      int64
# online_banking_flag                    int64
# tele_banking_flag                      int64
# creditcard_flag                        int64
# insurance_life_flag                    int64
# insurance_house_flag                   int64
# insurance_car_flag                     int64
# insurance_other_flag                   int64
# mortgage_flag                          int64
# portfolio_flag                         int64
# last_balance                         float64
# last_balance_minus_6_months          float64
# last_balance_minus_12_months         float64
# income_salary_per_year               float64
# income_deposits_per_year             float64
# income_securities_per_year           float64
# insurance_life_premium_per_month     float64
# insurance_house_premium_per_year     float64
# insurance_car_premium_per_year       float64
# mortgage_value                       float64
# mortgage_interest                    float64
# mortgage_downpayment                 float64
# mortgage_dayuntilmaturity              int64
# mortgage_numbers                       int64
# online_number_of_logins_per_month      int64
# online_tranactions_per_month           int64
# advisor_contacts_last12months          int64
# customer_limit                       float64
# cash_withdraws_per_month               int64
# cash_withdrawals_value               float64
# consumer_credit_value                float64
# consumer_credit_maturity               int64
# account_fee                            int64
# number_of_refusals                     int64
# dtype: object

# %%
# Add a new column "Target"
# This column will be used later on to feed the model
Data['Target'] = 0

# %%
# Check the new column added to the data set
Data.head().T
# Out:
#                                                        0           1  \
# contract_start                                2010-10-24  2010-04-30
# contract_end                                         NaN  2017-10-20
# date_of_birth                                 1991-02-11  1986-04-06
# gender                                                 M           W
# profession                         Professional Services         NaN
# size_household                                         1           1
# ZIP                                                76829       35104
# segment                                               S2          S2
# credit_rating                                    89.5685     94.2705
# no_credit_rating_flag                                  0           0
# main_account_flag                                      0           0
# online_banking_flag                                    0           1
# tele_banking_flag                                      1           1
# creditcard_flag                                        0           1
# insurance_life_flag                                    0           0
# insurance_house_flag                                   1           1
# insurance_car_flag                                     1           1
# insurance_other_flag                                   1           0
# mortgage_flag                                          1           1
# portfolio_flag                                         0           0
# last_balance                                     38694.4     77759.1
# last_balance_minus_6_months                      57898.1     67914.7
# last_balance_minus_12_months                     57993.5     55263.3
# income_salary_per_year                                 0           0
# income_deposits_per_year                               0           0
# income_securities_per_year                             0           0
# insurance_life_premium_per_month                       0           0
# insurance_house_premium_per_year                       0           0
# insurance_car_premium_per_year                         0           0
# mortgage_value                                         0           0
# mortgage_interest                                      0           0
# mortgage_downpayment                                   0           0
# mortgage_dayuntilmaturity                              0           0
# mortgage_numbers                                       0           0
# online_number_of_logins_per_month                      0          16
# online_tranactions_per_month                           0           8
# advisor_contacts_last12months                          3           2
# customer_limit                                      1000        1000
# cash_withdraws_per_month                               4           7
# cash_withdrawals_value                           459.841     476.334
# consumer_credit_value                           -24011.4    -5368.74
# consumer_credit_maturity                             205         137
# account_fee                                           15          15
# number_of_refusals                                     6           6
# Target                                                 0           0
#
#                                                 2                      3  \
# contract_start                         2013-05-02             2016-12-24
# contract_end                                  NaN                    NaN
# date_of_birth                          1993-04-18             1994-07-29
# gender                                          M                      W
# profession                         Transportation  Professional Services
# size_household                                  1                      2
# ZIP                                         63450                   9573
# segment                                        S2                     S3
# credit_rating                             93.0309                    NaN
# no_credit_rating_flag                           0                      1
# main_account_flag                               0                      1
# online_banking_flag                             1                      0
# tele_banking_flag                               0                      0
# creditcard_flag                                 1                      1
# insurance_life_flag                             0                      0
# insurance_house_flag                            1                      1
# insurance_car_flag                              1                      1
# insurance_other_flag                            0                      1
# mortgage_flag                                   1                      0
# portfolio_flag                                  0                      0
# last_balance                                46702                10917.8
# last_balance_minus_6_months               52687.3                9506.82
# last_balance_minus_12_months              56011.6                12194.7
# income_salary_per_year                          0                      0
# income_deposits_per_year                        0                      0
# income_securities_per_year                      0                      0
# insurance_life_premium_per_month                0                      0
# insurance_house_premium_per_year                0                486.581
# insurance_car_premium_per_year                  0                335.885
# mortgage_value                                  0                      0
# mortgage_interest                               0                      0
# mortgage_downpayment                            0                      0
# mortgage_dayuntilmaturity                       0                    104
# mortgage_numbers                                0                      0
# online_number_of_logins_per_month              26                      0
# online_tranactions_per_month                   12                      0
# advisor_contacts_last12months                   2                      4
# customer_limit                               1000                   1050
# cash_withdraws_per_month                        3                      4
# cash_withdrawals_value                     332.64                378.325
# consumer_credit_value                    -9678.71               -12110.3
# consumer_credit_maturity                      624                   1263
# account_fee                                    15                     10
# number_of_refusals                              4                      7
# Target                                          0                      0
#
#                                             4
# contract_start                     2011-10-01
# contract_end                              NaN
# date_of_birth                      1990-10-28
# gender                                      W
# profession                           Research
# size_household                              1
# ZIP                                     66916
# segment                                    S2
# credit_rating                         90.4577
# no_credit_rating_flag                       0
# main_account_flag                           0
# online_banking_flag                         1
# tele_banking_flag                           0
# creditcard_flag                             1
# insurance_life_flag                         0
# insurance_house_flag                        1
# insurance_car_flag                          1
# insurance_other_flag                        0
# mortgage_flag                               0
# portfolio_flag                              0
# last_balance                          26170.4
# last_balance_minus_6_months           29474.1
# last_balance_minus_12_months            16831
# income_salary_per_year                      0
# income_deposits_per_year                    0
# income_securities_per_year                  0
# insurance_life_premium_per_month            0
# insurance_house_premium_per_year            0
# insurance_car_premium_per_year              0
# mortgage_value                              0
# mortgage_interest                           0
# mortgage_downpayment                        0
# mortgage_dayuntilmaturity                   0
# mortgage_numbers                            0
# online_number_of_logins_per_month          23
# online_tranactions_per_month               18
# advisor_contacts_last12months               3
# customer_limit                           1000
# cash_withdraws_per_month                    4
# cash_withdrawals_value                471.509
# consumer_credit_value                       0
# consumer_credit_maturity                  521
# account_fee                                10
# number_of_refusals                          3
# Target                                      0

# %%
# Create 0 where 'contract_end' column values is Nan and 1 for the rest of the cases
Data['Target'] = np.where(Data['contract_end'].isna(), 0, 1) 
# Set 'Target' column as the target for the machine learning model
y = Data.Target
# Analyse the dataset and chose the relevant columns to generate the X variable
var_select = ["size_household", "income_deposits_per_year", "main_account_flag", "insurance_house_premium_per_year", "income_securities_per_year", "cash_withdraws_per_month"]
X = Data[var_select]

# %%
# Check number of churns present already in the dataset
Data.groupby('Target').size()
# Out:
# Target
# 0    95129
# 1     4871
# dtype: int64

# %%
Data.head().T
# Out:
#                                                        0                  1  \
# contract_start                                2010-10-24         2010-04-30
# contract_end                                         NaN         2017-10-20
# date_of_birth                                 1991-02-11         1986-04-06
# gender                                                 M                  W
# profession                         Professional Services                NaN
# size_household                                         1                  1
# ZIP                                                76829              35104
# segment                                               S2                 S2
# credit_rating                           89,5685176247469   94,2705069107966
# no_credit_rating_flag                                  0                  0
# main_account_flag                                      0                  0
# online_banking_flag                                    0                  1
# tele_banking_flag                                      1                  1
# creditcard_flag                                        0                  1
# insurance_life_flag                                    0                  0
# insurance_house_flag                                   1                  1
# insurance_car_flag                                     1                  1
# insurance_other_flag                                   1                  0
# mortgage_flag                                          1                  1
# portfolio_flag                                         0                  0
# last_balance                            38694,3768752972   77759,1305436596
# last_balance_minus_6_months             57898,0655263417   67914,6866703495
# last_balance_minus_12_months            57993,5440013713   55263,2702429917
# income_salary_per_year                                 0                  0
# income_deposits_per_year                               0                  0
# income_securities_per_year                             0                  0
# insurance_life_premium_per_month                       0                  0
# insurance_house_premium_per_year                       0                  0
# insurance_car_premium_per_year                         0                  0
# mortgage_value                                         0                  0
# mortgage_interest                                      0                  0
# mortgage_downpayment                                   0                  0
# mortgage_dayuntilmaturity                              0                  0
# mortgage_numbers                                       0                  0
# online_number_of_logins_per_month                      0                 16
# online_tranactions_per_month                           0                  8
# advisor_contacts_last12months                          3                  2
# customer_limit                                      1000               1000
# cash_withdraws_per_month                               4                  7
# cash_withdrawals_value                  459,840939712736   476,334458774319
# consumer_credit_value                   -24011,393551989  -5368,74306807524
# consumer_credit_maturity                             205                137
# account_fee                                           15                 15
# number_of_refusals                                     6                  6
# Target                                                 0                  1
#
#                                                    2                      3  \
# contract_start                            2013-05-02             2016-12-24
# contract_end                                     NaN                    NaN
# date_of_birth                             1993-04-18             1994-07-29
# gender                                             M                      W
# profession                            Transportation  Professional Services
# size_household                                     1                      2
# ZIP                                            63450                   9573
# segment                                           S2                     S3
# credit_rating                       93,0309465957283                    NaN
# no_credit_rating_flag                              0                      1
# main_account_flag                                  0                      1
# online_banking_flag                                1                      0
# tele_banking_flag                                  0                      0
# creditcard_flag                                    1                      1
# insurance_life_flag                                0                      0
# insurance_house_flag                               1                      1
# insurance_car_flag                                 1                      1
# insurance_other_flag                               0                      1
# mortgage_flag                                      1                      0
# portfolio_flag                                     0                      0
# last_balance                          46701,95648597       10917,7849719239
# last_balance_minus_6_months         52687,3292626823       9506,82086163218
# last_balance_minus_12_months        56011,5780893348       12194,6527938667
# income_salary_per_year                             0                      0
# income_deposits_per_year                           0                      0
# income_securities_per_year                         0                      0
# insurance_life_premium_per_month                   0                      0
# insurance_house_premium_per_year                   0       486,580576010278
# insurance_car_premium_per_year                     0       335,884723643912
# mortgage_value                                     0                      0
# mortgage_interest                                  0                      0
# mortgage_downpayment                               0                      0
# mortgage_dayuntilmaturity                          0                    104
# mortgage_numbers                                   0                      0
# online_number_of_logins_per_month                 26                      0
# online_tranactions_per_month                      12                      0
# advisor_contacts_last12months                      2                      4
# customer_limit                                  1000                   1050
# cash_withdraws_per_month                           3                      4
# cash_withdrawals_value              332,640202190496        378,32474448561
# consumer_credit_value              -9678,71341935483      -12110,3059156975
# consumer_credit_maturity                         624                   1263
# account_fee                                       15                     10
# number_of_refusals                                 4                      7
# Target                                             0                      0
#
#                                                   4
# contract_start                           2011-10-01
# contract_end                                    NaN
# date_of_birth                            1990-10-28
# gender                                            W
# profession                                 Research
# size_household                                    1
# ZIP                                           66916
# segment                                          S2
# credit_rating                        90,45766439571
# no_credit_rating_flag                             0
# main_account_flag                                 0
# online_banking_flag                               1
# tele_banking_flag                                 0
# creditcard_flag                                   1
# insurance_life_flag                               0
# insurance_house_flag                              1
# insurance_car_flag                                1
# insurance_other_flag                              0
# mortgage_flag                                     0
# portfolio_flag                                    0
# last_balance                       26170,3728543336
# last_balance_minus_6_months        29474,0655337622
# last_balance_minus_12_months       16830,9915503826
# income_salary_per_year                            0
# income_deposits_per_year                          0
# income_securities_per_year                        0
# insurance_life_premium_per_month                  0
# insurance_house_premium_per_year                  0
# insurance_car_premium_per_year                    0
# mortgage_value                                    0
# mortgage_interest                                 0
# mortgage_downpayment                              0
# mortgage_dayuntilmaturity                         0
# mortgage_numbers                                  0
# online_number_of_logins_per_month                23
# online_tranactions_per_month                     18
# advisor_contacts_last12months                     3
# customer_limit                                 1000
# cash_withdraws_per_month                          4
# cash_withdrawals_value             471,509299299279
# consumer_credit_value                             0
# consumer_credit_maturity                        521
# account_fee                                      10
# number_of_refusals                                3
# Target                                            0

# %%
# Split the dataset among training and testing groups
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
# Import the model. Logistic Regression is widely used
# when the target variable is binary
model = LogisticRegression()
result = model.fit(X_train, y_train)
prediction = model.predict(X_test)

# Measure the acurracy of the prediction by comparing 
# with the actual values obtained from the 'Target' column
print(metrics.accuracy_score(y_test, prediction))
# Out:
# c:\users\víctor\appdata\local\programs\python\python36-32\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9513

# %%
# Get the weights of the variables used in the logistic 
# regression model, to segment clients and apply 
# specific measures to decrease the likelihood of
# clients churn

w = pd.Series(model.coef_[0], index=X.columns.values)
w.sort_values(ascending=True)
# Out:
# size_household                     -8.908995e-01
# insurance_house_premium_per_year   -4.396566e-03
# income_deposits_per_year            8.442588e-07
# income_securities_per_year          1.357271e-05
# cash_withdraws_per_month            3.386978e-01
# main_account_flag                   1.874101e+00
# dtype: float64
